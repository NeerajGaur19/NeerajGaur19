# %% [markdown]
# #Hierarchichal Clustering
# - grouping similar things together, building a hierarchy (tree-like structure) of groups.
# - Why important? Because in real life we rarely know the exact number of clusters beforehand.
#
# ## DENDROGRAM
# - A tree-like diagram that shows how data points are merged or split step by step.
#
#
# ###1.  AGGLOMERATIVE CLUSTERING
# - **BOTTOM-UP** approach
# - Start with each data point as its own clusters
# - At each step, merge two closest clusters
# - Continue until everything merges into one big cluster
#
# ###2. DIVISIVE CLUSTERING
# - **TOP-DOWN** approach
# - Start with all data in one cluster
# - Split the cluster into smaller clusters step by step
# - Continue until each point is its own cluster
#
# **WHY NOT DIVISIVE??**
# 1. Not directly available in scipy or sklearn
# 2. Computationally complex/heavier
# 3. Interpretability -> agglomerative is better, divisive is harder to interpret
# 4. Real-world use: in practice, agglomerative is more stable and widely used, so libraries focus on it
# ------------------------------------------------------------------------
#
# ###REAL WORLD APPLICATIONS
# 1. Customer Segmentation(Retail,e-commerce)
# 2. Document Clustering(NLP, text mining)
# 3. Gene sequence analysis(bioinformatics)
# 4. Image grouping(computer vision)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Problem Statement**
# - You are working as a data analyst at a retail company. You have been provided with customer data and are tasked with identifying distinct customer groups using Hierarchical Clustering. Your goal is to help the marketing team target each customer segment more effectively.

# %%
# Dataset Link: https://drive.google.com/file/d/1kj_isJ2cHuhheK5PO3OjgNiit2FLQIDC/view?usp=sharing

# %%
#data loading
#data exploration
#EDA(isnull,duplicates)
#apply scaling on relevant columns only

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/hierarchical_clustering_data.csv')

# %%
df
# Out:
#      CustomerID  Annual_Income  Spending_Score  Age Region
# 0          1001          67450           17.58   31  North
# 1          1002          57926           11.35   27   West
# 2          1003          69715           64.01   38   East
# 3          1004          82845           70.94   48  North
# 4          1005          56487            4.13   16  North
# ..          ...            ...             ...  ...    ...
# 995        1996          55783           28.79   28  South
# 996        1997          86965           21.49   22   East
# 997        1998          69612           52.14   24   East
# 998        1999          51432            1.55   30  South
# 999        2000          68588            1.76   31   West
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      1000 non-null   int64
#  1   Annual_Income   1000 non-null   int64
#  2   Spending_Score  1000 non-null   float64
#  3   Age             1000 non-null   int64
#  4   Region          1000 non-null   object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#         CustomerID  Annual_Income  Spending_Score          Age
# count  1000.000000     1000.00000     1000.000000  1000.000000
# mean   1500.500000    60289.47500       50.861300    34.631000
# std     288.819436    14688.23654       28.547316     9.700667
# min    1001.000000    11380.00000        1.320000     4.000000
# 25%    1250.750000    50285.75000       25.475000    28.000000
# 50%    1500.500000    60379.00000       52.095000    35.000000
# 75%    1750.250000    69718.75000       74.887500    41.000000
# max    2000.000000   117790.00000       99.940000    66.000000

# %%
df.isnull().sum()
# Out:
# CustomerID        0
# Annual_Income     0
# Spending_Score    0
# Age               0
# Region            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Region'].value_counts()
# Out:
# Region
# South    274
# East     251
# North    240
# West     235
# Name: count, dtype: int64

# %%
df
# Out:
#      CustomerID  Annual_Income  Spending_Score  Age Region
# 0          1001          67450           17.58   31  North
# 1          1002          57926           11.35   27   West
# 2          1003          69715           64.01   38   East
# 3          1004          82845           70.94   48  North
# 4          1005          56487            4.13   16  North
# ..          ...            ...             ...  ...    ...
# 995        1996          55783           28.79   28  South
# 996        1997          86965           21.49   22   East
# 997        1998          69612           52.14   24   East
# 998        1999          51432            1.55   30  South
# 999        2000          68588            1.76   31   West
#
# [1000 rows x 5 columns]

# %%
#Scaling types:
#1. StandardScaler(Standardization): transform data to have a mean of 0 and a std dev of 1.
#- Its affected less by outliers and is the default choice for algorithms

#2. Min-MaxScaling(Normalization): Rescales the data to a fixed range, usually 0 to 1.

# %%
from sklearn.preprocessing import StandardScaler

ls=['Annual_Income', 'Spending_Score', 'Age']

x=df[ls]

# %%
x
# Out:
#      Annual_Income  Spending_Score  Age
# 0            67450           17.58   31
# 1            57926           11.35   27
# 2            69715           64.01   38
# 3            82845           70.94   48
# 4            56487            4.13   16
# ..             ...             ...  ...
# 995          55783           28.79   28
# 996          86965           21.49   22
# 997          69612           52.14   24
# 998          51432            1.55   30
# 999          68588            1.76   31
#
# [1000 rows x 3 columns]

# %%
sc=StandardScaler()
x_scaled=sc.fit_transform(x)

# %%
x_scaled
# Out:
# array([[ 0.48774459, -1.16641275, -0.37449145],
#        [-0.16098989, -1.38475612, -0.78704055],
#        [ 0.64202679,  0.46082368,  0.34746948],
#        ...,
#        [ 0.63501086,  0.04481472, -1.09645238],
#        [-0.60333363, -1.72821761, -0.47762872],
#        [ 0.56526033, -1.72085772, -0.37449145]])

# %%
from scipy.cluster.hierarchy import linkage,fcluster,dendrogram
#linkage: how clusters are merged step by step
#fcluster: final cluster -> dendrogram
#dendrogram: plot the dendrogram

# %%
#Single Linkage: merge clusters based on minimum distance
#Complete Linkage: merge clusters based on max distance
#Average Linkage: merge clusters based on avg distance

# %%
#research about a parameter that allows you to highlight distance in a visualization graph

# %%
plt.figure(figsize=(15,7))
#ward: minimize variance(most popular in the industry)
dendrogram(linkage(x_scaled,method='ward'))
plt.xlabel("number of clusters")
plt.ylabel("euclidean distance")
plt.title("Dendrogram")
plt.grid(True)
plt.show()

# %%
# Euclidean Distance: represents that shortest path between points: sqrt of sum of squared differences

# %% [markdown]
# 1. **Y-axis** - represents the distance(dissimilarity) at which clusters are merged
#    - Small height= very similar clusters
#    - Large height= very different clusters

# %%
#Optimal k is decided by identifying the highest euclidean distance and intersecting a horizontal line from it
#The number of vertical lines crossed by it decides the optimal k

# %%
#k=4 with distance ~=24 #number of clusters

# %%
link=linkage(x_scaled,method='ward')
#link has: (data points) which clusters got merged, at what distance they were merged, how many points were in each merge

cluster=fcluster(link,t=4,criterion='maxclust')
#t=4 with maxclust: FORM EXACTLY 4 CLUSTERS FROM THIS HIERARCHY

cluster
# Out:
# array([2, 2, 4, 4, 2, 3, 4, 4, 3, 3, 4, 3, 4, 3, 1, 3, 2, 3, 2, 3, 4, 3,
#        2, 1, 1, 2, 3, 4, 3, 2, 2, 4, 4, 2, 4, 3, 2, 3, 3, 4, 2, 4, 2, 2,
#        4, 1, 4, 3, 3, 2, 3, 4, 1, 4, 4, 3, 2, 1, 4, 4, 3, 1, 3, 4, 4, 1,
#        1, 2, 4, 4, 4, 3, 3, 3, 3, 1, 3, 4, 4, 4, 4, 3, 1, 2, 3, 3, 2, 4,
#        2, 3, 3, 2, 3, 4, 3, 4, 4, 2, 2, 4, 4, 3, 3, 3, 4, 1, 2, 2, 3, 4,
#        2, 2, 3, 1, 4, 3, 4, 2, 4, 4, 3, 4, 3, 2, 3, 2, 3, 2, 2, 1, 4, 4,
#        3, 4, 4, 4, 3, 4, 4, 4, 4, 4, 2, 2, 4, 4, 1, 4, 3, 2, 1, 1, 4, 4,
#        3, 3, 1, 4, 1, 2, 1, 2, 3, 4, 3, 4, 4, 4, 2, 2, 4, 4, 3, 3, 3, 3,
#        3, 1, 4, 3, 2, 2, 4, 4, 1, 4, 4, 1, 1, 1, 1, 3, 1, 4, 4, 4, 2, 1,
#        3, 3, 1, 4, 2, 2, 4, 4, 4, 4, 2, 4, 3, 4, 4, 2, 4, 3, 3, 4, 2, 2,
#        1, 2, 3, 4, 2, 4, 4, 4, 1, 4, 1, 4, 3, 2, 2, 2, 4, 3, 2, 3, 4, 1,
#        4, 2, 1, 1, 4, 3, 2, 3, 4, 4, 4, 3, 4, 4, 1, 1, 1, 2, 4, 2, 4, 2,
#        3, 3, 1, 1, 2, 4, 2, 4, 2, 3, 3, 4, 2, 2, 4, 4, 2, 2, 4, 4, 2, 4,
#        2, 1, 4, 4, 3, 1, 2, 3, 3, 3, 2, 1, 4, 4, 4, 2, 4, 4, 4, 2, 4, 4,
#        4, 1, 3, 4, 2, 4, 4, 3, 3, 4, 3, 1, 3, 4, 2, 3, 4, 2, 3, 3, 4, 3,
#        2, 1, 2, 3, 4, 4, 2, 3, 4, 3, 3, 4, 4, 1, 3, 3, 3, 1, 3, 1, 1, 1,
#        4, 1, 4, 3, 4, 4, 2, 3, 4, 4, 4, 4, 1, 3, 1, 1, 2, 4, 4, 2, 2, 3,
#        2, 2, 2, 2, 4, 4, 2, 4, 2, 4, 4, 4, 3, 1, 3, 1, 3, 4, 1, 3, 2, 3,
#        4, 2, 3, 4, 2, 4, 4, 2, 3, 3, 4, 3, 4, 4, 4, 3, 4, 4, 4, 1, 4, 3,
#        4, 4, 3, 2, 1, 4, 4, 4, 1, 3, 4, 4, 3, 4, 4, 4, 3, 4, 4, 1, 3, 4,
#        4, 1, 1, 2, 4, 2, 1, 4, 1, 1, 4, 2, 3, 4, 4, 4, 3, 4, 2, 2, 4, 1,
#        1, 3, 4, 4, 2, 4, 1, 4, 1, 4, 4, 4, 3, 4, 4, 4, 2, 4, 4, 4, 3, 4,
#        4, 3, 4, 2, 2, 1, 1, 2, 1, 3, 3, 4, 4, 4, 3, 2, 2, 2, 4, 2, 2, 2,
#        3, 1, 4, 1, 1, 2, 2, 4, 2, 4], dtype=int32)

# %%
df['ClusterID']=cluster

# %%
df
# Out:
#      CustomerID  Annual_Income  Spending_Score  Age Region  ClusterID
# 0          1001          67450           17.58   31  North          2
# 1          1002          57926           11.35   27   West          2
# 2          1003          69715           64.01   38   East          4
# 3          1004          82845           70.94   48  North          4
# 4          1005          56487            4.13   16  North          2
# ..          ...            ...             ...  ...    ...        ...
# 995        1996          55783           28.79   28  South          2
# 996        1997          86965           21.49   22   East          2
# 997        1998          69612           52.14   24   East          4
# 998        1999          51432            1.55   30  South          2
# 999        2000          68588            1.76   31   West          4
#
# [1000 rows x 6 columns]

# %%
#pairplot is a plot with histogram in the diagonal(univariate) and scatter plot for the rest(bivariate)
#KDE: Kernel Density Estimation: smoother version of histogram
#hue: differentiates categories of a column using different colors

# %%
sns.pairplot(df,hue='ClusterID', vars=['Annual_Income','Spending_Score','Age'], palette='Set2')
plt.show()

# %%
#3D Visualization
import plotly.express as px

# %%
fig=px.scatter_3d(df,x='Annual_Income', y='Spending_Score', z='Age',color='ClusterID', hover_name='CustomerID',title='3D Visualization')
fig.update_layout(scene=dict(xaxis_title='Annual_income', yaxis_title="Spending_score", zaxis_title='Age'), width=1000, height=900)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="74b9b141-9220-437e-afad-e8b1d0446712" class="plotly-graph-div" style="height:900px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74b9b141-9220-437e-afad-e8b1d0446712")) {                    Plotly.newPlot(                        "74b9b141-9220-437e-afad-e8b1d0446712",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eAnnual_Income=%{x}\u003cbr\u003eSpending_Score=%{y}\u003cbr\u003eAge=%{z}\u003cbr\u003eClusterID=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":[1001.0,1002.0,1003.0,1004.0,1005.0,1006.0,1007.0,1008.0,1009.0,1010.0,1011.0,1012.0,1013.0,1014.0,1015.0,1016.0,1017.0,1018.0,1019.0,1020.0,1021.0,1022.0,1023.0,1024.0,1025.0,1026.0,1027.0,1028.0,1029.0,1030.0,1031.0,1032.0,1033.0,1034.0,1035.0,1036.0,1037.0,1038.0,1039.0,1040.0,1041.0,1042.0,1043.0,1044.0,1045.0,1046.0,1047.0,1048.0,1049.0,1050.0,1051.0,1052.0,1053.0,1054.0,1055.0,1056.0,1057.0,1058.0,1059.0,1060.0,1061.0,1062.0,1063.0,1064.0,1065.0,1066.0,1067.0,1068.0,1069.0,1070.0,1071.0,1072.0,1073.0,1074.0,1075.0,1076.0,1077.0,1078.0,1079.0,1080.0,1081.0,1082.0,1083.0,1084.0,1085.0,1086.0,1087.0,1088.0,1089.0,1090.0,1091.0,1092.0,1093.0,1094.0,1095.0,1096.0,1097.0,1098.0,1099.0,1100.0,1101.0,1102.0,1103.0,1104.0,1105.0,1106.0,1107.0,1108.0,1109.0,1110.0,1111.0,1112.0,1113.0,1114.0,1115.0,1116.0,1117.0,1118.0,1119.0,1120.0,1121.0,1122.0,1123.0,1124.0,1125.0,1126.0,1127.0,1128.0,1129.0,1130.0,1131.0,1132.0,1133.0,1134.0,1135.0,1136.0,1137.0,1138.0,1139.0,1140.0,1141.0,1142.0,1143.0,1144.0,1145.0,1146.0,1147.0,1148.0,1149.0,1150.0,1151.0,1152.0,1153.0,1154.0,1155.0,1156.0,1157.0,1158.0,1159.0,1160.0,1161.0,1162.0,1163.0,1164.0,1165.0,1166.0,1167.0,1168.0,1169